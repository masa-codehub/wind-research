# %% [markdown]
# # 気象庁HTMLテーブル解析 PoC
#
# このノートブックでは、気象庁のサンプルHTML（例: `tests/resources/sample_jma.html`）を使い、
# - pandas.read_html
# - Beautiful Soup
# の2通りで風況データテーブルを抽出する方法を比較します。

# %% [markdown]
# ## 1. サンプルHTMLの準備
#
# `tests/resources/sample_jma.html` に気象庁のHTMLを保存してください。

# %%
# pandas.read_html を使ったテーブル抽出
import pandas as pd

# サンプルHTMLファイルのパス
html_path = "../tests/resources/sample_jma.html"

# HTML内の全テーブルをDataFrameリストとして取得
# encodingは必要に応じて調整
try:
    dfs = pd.read_html(html_path, encoding="utf-8")
    print(f"検出されたテーブル数: {len(dfs)}")
    # 例: 5番目のテーブルを表示
    display(dfs[4])
except Exception as e:
    print(f"pandas.read_htmlでの抽出に失敗: {e}")
# Out:
# 検出されたテーブル数: 2
# pandas.read_htmlでの抽出に失敗: list index out of range

# %%
# Beautiful Soup を使ったテーブル抽出
from bs4 import BeautifulSoup

with open(html_path, "r", encoding="utf-8") as f:
    html_content = f.read()

soup = BeautifulSoup(html_content, "lxml")

# 例: id="tablefix1" のテーブルを抽出
data_table = soup.find("table", id="tablefix1")
if data_table:
    rows = data_table.find_all("tr")
    for row in rows[2:]:  # ヘッダー行をスキップ
        cols = row.find_all("td")
        if len(cols) >= 3:
            time = cols[0].text.strip()
            direction = cols[1].text.strip()
            speed = cols[2].text.strip()
            print(f"{time}, {direction}, {speed}")
else:
    print("指定したテーブルが見つかりませんでした")
# Out:
# 00:10, 1007.1, 1009.9
# 00:20, 1007.0, 1009.8
# 00:30, 1007.0, 1009.8
# 00:40, 1007.1, 1009.9
# 00:50, 1007.1, 1009.9
# 01:00, 1007.3, 1010.1
# 01:10, 1007.4, 1010.2
# 01:20, 1007.5, 1010.3
# 01:30, 1007.5, 1010.3
# 01:40, 1007.6, 1010.4
# 01:50, 1008.0, 1010.8
# 02:00, 1007.9, 1010.7
# 02:10, 1008.1, 1010.9
# 02:20, 1008.2, 1011.0
# 02:30, 1008.6, 1011.4
# 02:40, 1008.7, 1011.5
# 02:50, 1008.9, 1011.7
# 03:00, 1009.0, 1011.8
# 03:10, 1008.9, 1011.7
# 03:20, 1009.1, 1011.9
# 03:30, 1009.2, 1012.0
# 03:40, 1009.2, 1012.0
# 03:50, 1009.4, 1012.2
# 04:00, 1009.6, 1012.4
# 04:10, 1009.7, 1012.5
# 04:20, 1009.7, 1012.5
# 04:30, 1009.8, 1012.6
# 04:40, 1010.5, 1013.3
# 04:50, 1010.6, 1013.5
# 05:00, 1010.7, 1013.6
# 05:10, 1010.7, 1013.6
# 05:20, 1010.9, 1013.8
# 05:30, 1011.1, 1014.0
# 05:40, 1011.3, 1014.2
# 05:50, 1011.3, 1014.2
# 06:00, 1011.6, 1014.5
# 06:10, 1011.9, 1014.8
# 06:20, 1011.9, 1014.8
# 06:30, 1012.1, 1015.0
# 06:40, 1012.5, 1015.4
# 06:50, 1012.6, 1015.5
# 07:00, 1012.6, 1015.5
# 07:10, 1012.7, 1015.6
# 07:20, 1012.7, 1015.6
# 07:30, 1012.7, 1015.6
# 07:40, 1012.9, 1015.7
# 07:50, 1013.0, 1015.9
# 08:00, 1013.0, 1015.8
# 08:10, 1013.2, 1016.0
# 08:20, 1013.3, 1016.1
# 08:30, 1013.5, 1016.3
# 08:40, 1013.6, 1016.4
# 08:50, 1013.5, 1016.3
# 09:00, 1013.6, 1016.4
# 09:10, 1013.7, 1016.5
# 09:20, 1013.9, 1016.7
# 09:30, 1013.9, 1016.7
# 09:40, 1013.9, 1016.7
# 09:50, 1014.1, 1016.9
# 10:00, 1014.2, 1017.0
# 10:10, 1014.2, 1017.0
# 10:20, 1014.1, 1016.9
# 10:30, 1014.1, 1016.9
# 10:40, 1014.0, 1016.8
# 10:50, 1014.2, 1017.0
# 11:00, 1014.3, 1017.1
# 11:10, 1014.3, 1017.1
# 11:20, 1014.3, 1017.1
# 11:30, 1014.2, 1017.0
# 11:40, 1014.2, 1017.0
# 11:50, 1014.4, 1017.2
# 12:00, 1014.3, 1017.1
# 12:10, 1014.4, 1017.2
# 12:20, 1014.5, 1017.3
# 12:30, 1014.5, 1017.3
# 12:40, 1014.6, 1017.4
# 12:50, 1014.5, 1017.3
# 13:00, 1014.5, 1017.3
# 13:10, 1014.4, 1017.2
# 13:20, 1014.4, 1017.2
# 13:30, 1014.5, 1017.3
# 13:40, 1014.7, 1017.5
# 13:50, 1014.7, 1017.5
# 14:00, 1014.9, 1017.7
# 14:10, 1014.8, 1017.6
# 14:20, 1014.7, 1017.5
# 14:30, 1014.6, 1017.4
# 14:40, 1014.9, 1017.7
# 14:50, 1014.8, 1017.6
# 15:00, 1015.0, 1017.8
# 15:10, 1014.9, 1017.7
# 15:20, 1015.0, 1017.8
# 15:30, 1015.1, 1017.9
# 15:40, 1015.0, 1017.8
# 15:50, 1015.2, 1018.0
# 16:00, 1015.4, 1018.2
# 16:10, 1015.4, 1018.2
# 16:20, 1015.4, 1018.2
# 16:30, 1015.8, 1018.6
# 16:40, 1015.9, 1018.8
# 16:50, 1015.9, 1018.8
# 17:00, 1016.0, 1018.9
# 17:10, 1016.0, 1018.9
# 17:20, 1015.9, 1018.8
# 17:30, 1016.2, 1019.1
# 17:40, 1016.4, 1019.3
# 17:50, 1016.5, 1019.4
# 18:00, 1016.6, 1019.5
# 18:10, 1016.4, 1019.3
# 18:20, 1016.4, 1019.3
# 18:30, 1016.6, 1019.5
# 18:40, 1016.7, 1019.6
# 18:50, 1016.9, 1019.8
# 19:00, 1017.0, 1019.9
# 19:10, 1017.0, 1019.9
# 19:20, 1017.2, 1020.1
# 19:30, 1017.5, 1020.4
# 19:40, 1017.7, 1020.6
# 19:50, 1017.8, 1020.7
# 20:00, 1017.8, 1020.7
# 20:10, 1017.7, 1020.6
# 20:20, 1017.9, 1020.8
# 20:30, 1018.1, 1021.0
# 20:40, 1018.3, 1021.2
# 20:50, 1018.3, 1021.2
# 21:00, 1018.2, 1021.1
# 21:10, 1018.5, 1021.4
# 21:20, 1018.7, 1021.6
# 21:30, 1018.6, 1021.5
# 21:40, 1018.7, 1021.6
# 21:50, 1018.9, 1021.8
# 22:00, 1018.9, 1021.8
# 22:10, 1019.1, 1022.0
# 22:20, 1019.2, 1022.1
# 22:30, 1019.3, 1022.2
# 22:40, 1019.2, 1022.1
# 22:50, 1019.1, 1022.0
# 23:00, 1019.0, 1021.9
# 23:10, 1018.9, 1021.8
# 23:20, 1019.1, 1022.0
# 23:30, 1019.1, 1022.0
# 23:40, 1018.9, 1021.8
# 23:50, 1018.9, 1021.8
# 24:00, 1018.8, 1021.7

# %% [markdown]
# ## 2. 比較ポイント
#
# - コード量・実装の簡単さ
# - テーブル構造の変化への耐性
# - 必要なデータの抽出容易性
#
# この結果をもとに、どちらのライブラリを採用するか決定します。
